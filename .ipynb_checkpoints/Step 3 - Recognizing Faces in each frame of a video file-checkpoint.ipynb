# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from scipy import misc
import cv2
import numpy as np
from library import facenet
from library import detect_face
import os
import time
import pickle
import PIL
from PIL import Image
from datetime import datetime

input_video="example_mov.avi"
modeldir = './model/20191012-185253.pb'
classifier_filename = './class/classifier.pkl'
npy='./npy'
train_img="./face_dataset"
names = []

# def markAttendance(name):
#     with open('Y:\\Masters_Content\\Software_development_for_AI\\Project 2\\Attendance Tracking 1\\Face-Detection-and-Recogition-TF-FN-OCV-master\\Attendance.csv','r+') as f:
#         myDataList = [x.strip() for x in f.readlines()]
#         nameList = []
#         for line in myDataList:
#             entry = line.split(',')
#             nameList.append(entry[0])
#         if name not in nameList:
#             now = datetime.now()
#             dtString = now.strftime('%H:%M:%S')
#             f.writelines(f'{name},{dtString}\n') 

with tf.Graph().as_default():
    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.6)
    sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options, log_device_placement=False))
    with sess.as_default():
        pnet, rnet, onet = detect_face.create_mtcnn(sess, npy)

        minsize = 20  # minimum size of face
        threshold = [0.6, 0.7, 0.7]  # three steps's threshold
        factor = 0.709  # scale factor
        margin = 44
        frame_interval = 3
        batch_size = 1000
        image_size = 182
        input_image_size = 160
        
        HumanNames = os.listdir(train_img)
        HumanNames.sort()

        print('Loading Modal')
        facenet.load_model(modeldir)
        images_placeholder = tf.get_default_graph().get_tensor_by_name("input:0")
        embeddings = tf.get_default_graph().get_tensor_by_name("embeddings:0")
        phase_train_placeholder = tf.get_default_graph().get_tensor_by_name("phase_train:0")
        embedding_size = embeddings.get_shape()[1]


        classifier_filename_exp = os.path.expanduser(classifier_filename)
        with open(classifier_filename_exp, 'rb') as infile:
            (model, class_names) = pickle.load(infile)

        video_capture = cv2.VideoCapture(0)
        c = 0


        print('Start Recognition')
        prevTime = 0
        while True:
            ret, frame = video_capture.read()

            frame = cv2.resize(frame, (0,0), fx=0.5, fy=0.5)    #resize frame (optional)

            curTime = time.time()+1    # calc fps
            timeF = frame_interval

            if (c % timeF == 0):
                find_results = []

                if frame.ndim == 2:
                    frame = facenet.to_rgb(frame)
                frame = frame[:, :, 0:3]
                bounding_boxes, _ = detect_face.detect_face(frame, minsize, pnet, rnet, onet, threshold, factor)
                nrof_faces = bounding_boxes.shape[0]
#                 print('Detected_FaceNum: %d' % nrof_faces)

                if nrof_faces > 0:
                    det = bounding_boxes[:, 0:4]
                    img_size = np.asarray(frame.shape)[0:2]

                    cropped = []
                    scaled = []
                    scaled_reshape = []
                    bb = np.zeros((nrof_faces,4), dtype=np.int32)

                    for i in range(nrof_faces):
                        emb_array = np.zeros((1, embedding_size))

                        bb[i][0] = det[i][0]
                        bb[i][1] = det[i][1]
                        bb[i][2] = det[i][2]
                        bb[i][3] = det[i][3]

                        # inner exception
                        if bb[i][0] <= 0 or bb[i][1] <= 0 or bb[i][2] >= len(frame[0]) or bb[i][3] >= len(frame):
                            print('Face is very close!')
                            continue

                        cropped.append(frame[bb[i][1]:bb[i][3], bb[i][0]:bb[i][2], :])
                        cropped[i] = facenet.flip(cropped[i], False)
                        scaled.append(np.array(Image.fromarray(cropped[i]).resize((image_size, image_size),resample=PIL.Image.BILINEAR)))
                        scaled[i] = cv2.resize(scaled[i], (input_image_size,input_image_size),
                                               interpolation=cv2.INTER_CUBIC)
                        scaled[i] = facenet.prewhiten(scaled[i])
                        scaled_reshape.append(scaled[i].reshape(-1,input_image_size,input_image_size,3))
                        feed_dict = {images_placeholder: scaled_reshape[i], phase_train_placeholder: False}
                        emb_array[0, :] = sess.run(embeddings, feed_dict=feed_dict)
                        predictions = model.predict_proba(emb_array)
#                         print('predictions:',predictions)
#                         pred_ = sorted(predictions[0])
#                         print('predict:',pred_)
                        best_class_indices = np.argmax(predictions, axis=1)
#                         print('best_class_indices:',best_class_indices)
                        best_class_probabilities = predictions[np.arange(len(best_class_indices)), best_class_indices]
                        #print("predictions")
                        print('Class',best_class_indices,'is detected with accuracy ',best_class_probabilities)

                        # print(best_class_probabilities)
                        if best_class_probabilities>0.53:
                            cv2.rectangle(frame, (bb[i][0], bb[i][1]), (bb[i][2], bb[i][3]), (0, 255, 0), 2)    #boxing face

                            #plot result idx under box
                            text_x = bb[i][0]
                            text_y = bb[i][3] + 20
#                             print('Result Indices: ', best_class_indices)
#                             print(HumanNames)
                            for H_i in HumanNames:
                                if HumanNames[best_class_indices[0]] == H_i:
                                    result_names = HumanNames[best_class_indices[0]].upper()
                                    names.append(result_names)
#                                     markAttendance(result_names)
                                    cv2.putText(frame, result_names, (text_x, text_y), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                                                1, (0, 0, 255), thickness=1, lineType=2)
                        else:
                            continue
            # c+=1
            cv2.imshow('Video', frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        video_capture.release()
        cv2.destroyAllWindows()
        names = list( dict.fromkeys(names))
# Out:
# Loading Modal
# Model filename: ./model/20191012-185253.pb
# Start Recognition
# Class  [0] is detected with accuracy  [0.79168417]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7341207]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.75201411]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7553501]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.74587472]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.71867063]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.74389154]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.74402802]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.75246256]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76069581]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.74241895]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.73731475]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.75509919]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.75578762]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76471905]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77324143]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77995582]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78584065]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.75875594]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78888638]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.75683763]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.74761638]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.80285843]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77681616]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76840599]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77336702]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7457922]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.75052736]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.73507052]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.71697704]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7997911]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76982622]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77393382]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78811554]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7829204]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79610907]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78359332]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7596996]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.80241775]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7977067]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.83956234]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76618963]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.67528115]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77908739]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.82145801]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79457614]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76688887]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.82690703]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.84524556]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.73724142]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78387043]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77561688]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7973279]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.81167858]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79149431]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.77589631]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.81884207]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.84489355]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.84335529]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.81211812]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.81952922]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.82733134]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79384994]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79203312]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.80482949]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78948418]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.84806446]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.83929626]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.83920733]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79233152]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.8101356]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.83839604]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.82381813]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.84666973]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79566633]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.7886753]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79659738]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.67380617]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.65920404]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.69974344]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.68870257]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.57978143]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.53909104]
# Result Indices:  [0]
# Class  [3] is detected with accuracy  [0.46916105]
# Class  [0] is detected with accuracy  [0.57107715]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.47128687]
# Class  [0] is detected with accuracy  [0.45885601]
# Class  [3] is detected with accuracy  [0.63344253]
# Result Indices:  [3]
# Class  [0] is detected with accuracy  [0.52550022]
# Class  [0] is detected with accuracy  [0.59157165]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.74165444]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78263847]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.78242839]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.82787638]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.79598785]
# Result Indices:  [0]
# Class  [3] is detected with accuracy  [0.92410373]
# Result Indices:  [3]
# Class  [0] is detected with accuracy  [0.84833773]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.84104717]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.8557352]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.81878706]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0

# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76781621]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.76800321]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.56304269]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.54306692]
# Result Indices:  [0]
# Class  [3] is detected with accuracy  [0.5000733]
# Class  [3] is detected with accuracy  [0.54680349]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.46164735]
# Class  [3] is detected with accuracy  [0.37996076]
# Class  [3] is detected with accuracy  [0.46104153]
# Class  [3] is detected with accuracy  [0.46915075]
# Class  [3] is detected with accuracy  [0.38269333]
# Class  [3] is detected with accuracy  [0.6869089]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.98566282]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.94247649]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.59589155]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.65764768]
# Result Indices:  [3]
# Class  [1] is detected with accuracy  [0.48779176]
# Class  [3] is detected with accuracy  [0.49898837]
# Class  [3] is detected with accuracy  [0.45857061]
# Class  [3] is detected with accuracy  [0.54276647]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.45776205]
# Class  [3] is detected with accuracy  [0.41524685]
# Class  [3] is detected with accuracy  [0.4093752]
# Class  [3] is detected with accuracy  [0.51241822]
# Class  [3] is detected with accuracy  [0.39935944]
# Class  [2] is detected with accuracy  [0.36953634]
# Class  [3] is detected with accuracy  [0.3717272]
# Class  [3] is detected with accuracy  [0.42673755]
# Class  [3] is detected with accuracy  [0.38420154]
# Class  [3] is detected with accuracy  [0.46545776]
# Class  [3] is detected with accuracy  [0.39455656]
# Class  [2] is detected with accuracy  [0.37496159]
# Class  [3] is detected with accuracy  [0.4223038]
# Class  [3] is detected with accuracy  [0.41033611]
# Class  [3] is detected with accuracy  [0.39502672]
# Class  [3] is detected with accuracy  [0.43527987]
# Class  [3] is detected with accuracy  [0.34984605]
# Class  [3] is detected with accuracy  [0.42605572]
# Class  [1] is detected with accuracy  [0.53851766]
# Result Indices:  [1]
# Class  [1] is detected with accuracy  [0.38330622]
# Class  [2] is detected with accuracy  [0.33733598]
# Class  [3] is detected with accuracy  [0.37271675]
# Class  [3] is detected with accuracy  [0.45425189]
# Class  [3] is detected with accuracy  [0.46527792]
# Class  [1] is detected with accuracy  [0.43351824]
# Class  [3] is detected with accuracy  [0.36322801]
# Class  [3] is detected with accuracy  [0.4156992]
# Class  [1] is detected with accuracy  [0.42747124]
# Class  [1] is detected with accuracy  [0.42062583]
# Class  [1] is detected with accuracy  [0.4238814]
# Class  [1] is detected with accuracy  [0.44392001]
# Class  [2] is detected with accuracy  [0.40061295]
# Class  [3] is detected with accuracy  [0.34656238]
# Class  [3] is detected with accuracy  [0.40996993]
# Class  [3] is detected with accuracy  [0.47115965]
# Class  [3] is detected with accuracy  [0.35462043]
# Class  [3] is detected with accuracy  [0.42070087]
# Class  [3] is detected with accuracy  [0.48015894]
# Class  [3] is detected with accuracy  [0.40946086]
# Class  [3] is detected with accuracy  [0.46347794]
# Class  [2] is detected with accuracy  [0.36397892]
# Class  [3] is detected with accuracy  [0.52798698]
# Class  [3] is detected with accuracy  [0.91912487]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.66596508]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.85747813]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.84115719]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.42119572]
# Class  [3] is detected with accuracy  [0.37823337]
# Class  [3] is detected with accuracy  [0.52538403]
# Class  [1] is detected with accuracy  [0.50411051]
# Class  [3] is detected with accuracy  [0.49967644]
# Class  [1] is detected with accuracy  [0.55237059]
# Result Indices:  [1]
# Class  [3] is detected with accuracy  [0.45541484]
# Class  [3] is detected with accuracy  [0.48759661]
# Class  [3] is detected with accuracy  [0.53067621]
# Result Indices:  [3]
# Class  [3] is detected with accuracy  [0.50660539]
# Class  [3] is detected with accuracy  [0.38918376]
# Class  [3] is detected with accuracy  [0.40274568]
# Class  [3] is detected with accuracy  [0.44253305]
# Class  [1] is detected with accuracy  [0.5346912]
# Result Indices:  [1]
# Class  [1] is detected with accuracy  [0.6651143]
# Result Indices:  [1]
# Class  [3] is detected with accuracy  [0.44616336]
# Class  [3] is detected with accuracy  [0.44862475]
# Class  [1] is detected with accuracy  [0.37350484]
# Class  [1] is detected with accuracy  [0.48068821]
# Class  [1] is detected with accuracy  [0.5003349]
# Class  [1] is detected with accuracy  [0.4398842]
# Class  [3] is detected with accuracy  [0.48290162]
# Class  [1] is detected with accuracy  [0.32601634]
# Class  [3] is detected with accuracy  [0.36402859]
# Class  [1] is detected with accuracy  [0.52575056]
# Class  [1] is detected with accuracy  [0.53920625]
# Result Indices:  [1]
# Class  [3] is detected with accuracy  [0.368308]
# Class  [2] is detected with accuracy  [0.37543533]
# Class  [1] is detected with accuracy  [0.54095365]
# Result Indices:  [1]
# Class  [1] is detected with accuracy  [0.64784234]
# Result Indices:  [1]
# Class  [2] is detected with accuracy  [0.36559539]
# Class  [1] is detected with accuracy  [0.42857743]
# Class  [1] is detected with accuracy  [0.48908124]
# Class  [1] is detected with accuracy  [0.67606806]
# Result Indices:  [1]
# Class  [1] is detected with accuracy  [0.49698757]
# Class  [1] is detected with accuracy  [0.55162954]
# Result Indices:  [1]
# Class  [1] is detected with accuracy  [0.36473281]
# Class  [1] is detected with accuracy  [0.45715312]
# Class  [1] is detected with accuracy  [0.48892828]
# Class  [1] is detected with accuracy  [0.33577563]
# Class  [3] is detected with accuracy  [0.38776136]
# Class  [1] is detected with accuracy  [0.64044026]
# Result Indices:  [1]
# Class  [3] is detected with accuracy  [0.45330065]
# Class  [1] is detected with accuracy  [0.44019765]
# Class  [2] is detected with accuracy  [0.35527136]
# Class  [1] is detected with accuracy  [0.6660844]
# Result Indices:  [1]
# Class  [1] is detected with accuracy  [0.45993713]
# Class  [3] is detected with accuracy  [0.40627782]
# Class  [1] is detected with accuracy  [0.60585592]
# Result Indices:  [1]
# Class  [3] is detected with accuracy  [0.34967358]
# Class  [1] is detected with accuracy  [0.47238024]
# Class  [1] is detected with accuracy  [0.55427414]
# Result Indices:  [1]
# Class  [1] is detected with accuracy  [0.44850975]
# Class  [0] is detected with accuracy  [0.5297335]
# Class  [0] is detected with accuracy  [0.64887356]
# Result Indices:  [0]
# Class  [0] is detected with accuracy  [0.